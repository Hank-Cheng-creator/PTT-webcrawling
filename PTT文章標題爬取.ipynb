# %%
import requests
from bs4 import BeautifulSoup
res = requests.get("https://www.ptt.cc/bbs/Food/index7000.html")
soup = BeautifulSoup(res.text, 'html.parser')

# %%
res.text
# Out:
# '<!DOCTYPE html>\n<html>\n\t<head>\n\t\t<meta charset="utf-8">\n\t\t\n\n<meta name="viewport" content="width=device-width, initial-scale=1">\n\n<title>看板 Food 文章列表 - 批踢踢實業坊</title>\n\n<link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">\n<link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">\n<link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">\n<link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">\n<link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">\n\n\n\n\n\t</head>\n    <body>\n\t\t\n<div id="topbar-container">\n\t<div id="topbar" class="bbs-content">\n\t\t<a id="logo" href="/bbs/">批踢踢實業坊</a>\n\t\t<span>&rsaquo;</span>\n\t\t<a class="board" href="/bbs/Food/index.html"><span class="board-label">看板 </span>Food</a>\n\t\t<a class="right small" href="/about.html">關於我們</a>\n\
# ...

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>看板 Food 文章列表 - 批踢踢實業坊</title>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-custom.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <div id="topbar-container">
# <div class="bbs-content" id="topbar">
# <a href="/bbs/" id="logo">批踢踢實業坊</a>
# <span>›</span>
# <a class="board" href="/bbs/Food/index.html"><span class="board-label">看板 </span>Food</a>
# <a class="right small" href="/about.html">關於我們</a>
# ...

# %%
soup.select('a')
# Out:
# [<a href="/bbs/" id="logo">批踢踢實業坊</a>,
#  <a class="board" href="/bbs/Food/index.html"><span class="board-label">看板 </span>Food</a>,
#  <a class="right small" href="/about.html">關於我們</a>,
#  <a class="right small" href="/contact.html">聯絡資訊</a>,
#  <a class="btn selected" href="/bbs/Food/index.html">看板</a>,
#  <a class="btn" href="/man/Food/index.html">精華區</a>,
#  <a class="btn wide" href="/bbs/Food/index1.html">最舊</a>,
#  <a class="btn wide" href="/bbs/Food/index6999.html">‹ 上頁</a>,
#  <a class="btn wide" href="/bbs/Food/index7001.html">下頁 ›</a>,
#  <a class="btn wide" href="/bbs/Food/index.html">最新</a>,
#  <a href="/bbs/Food/M.1618664116.A.AD3.html">[食記] 台北.大同 - 林家鯊魚煙</a>,
#  <a href="/bbs/Food/search?q=thread%3A%5B%E9%A3%9F%E8%A8%98%5D+%E5%8F%B0%E5%8C%97.%E5%A4%A7%E5%90%8C+-+%E6%9E%97%E5%AE%B6%E9%AF%8A%E9%AD%9A%E7%85%99">搜尋同標題文章</a>,
#  <a href="/bbs/Food/search?q=author%3Ab122771">搜尋看板內 b122771 的文章</a>,
#  <a href="/bbs/Food/M.1618664540.A.4AB.html">[食記] 台北.大同 - 汕頭牛肉麵</a>,
# ...

# %%
clean = soup.select('a')

# %%
clean
# Out:
# [<a href="/bbs/" id="logo">批踢踢實業坊</a>,
#  <a class="board" href="/bbs/Food/index.html"><span class="board-label">看板 </span>Food</a>,
#  <a class="right small" href="/about.html">關於我們</a>,
#  <a class="right small" href="/contact.html">聯絡資訊</a>,
#  <a class="btn selected" href="/bbs/Food/index.html">看板</a>,
#  <a class="btn" href="/man/Food/index.html">精華區</a>,
#  <a class="btn wide" href="/bbs/Food/index1.html">最舊</a>,
#  <a class="btn wide" href="/bbs/Food/index6999.html">‹ 上頁</a>,
#  <a class="btn wide" href="/bbs/Food/index7001.html">下頁 ›</a>,
#  <a class="btn wide" href="/bbs/Food/index.html">最新</a>,
#  <a href="/bbs/Food/M.1618664116.A.AD3.html">[食記] 台北.大同 - 林家鯊魚煙</a>,
#  <a href="/bbs/Food/search?q=thread%3A%5B%E9%A3%9F%E8%A8%98%5D+%E5%8F%B0%E5%8C%97.%E5%A4%A7%E5%90%8C+-+%E6%9E%97%E5%AE%B6%E9%AF%8A%E9%AD%9A%E7%85%99">搜尋同標題文章</a>,
#  <a href="/bbs/Food/search?q=author%3Ab122771">搜尋看板內 b122771 的文章</a>,
#  <a href="/bbs/Food/M.1618664540.A.4AB.html">[食記] 台北.大同 - 汕頭牛肉麵</a>,
# ...

# %%
clean = soup.select('.title a')

# %%
clean
# Out:
# [<a href="/bbs/Food/M.1618664116.A.AD3.html">[食記] 台北.大同 - 林家鯊魚煙</a>,
#  <a href="/bbs/Food/M.1618664540.A.4AB.html">[食記] 台北.大同 - 汕頭牛肉麵</a>,
#  <a href="/bbs/Food/M.1618665114.A.69D.html">[食記] 台北.大同 - 阿寶師 鱔魚麵</a>,
#  <a href="/bbs/Food/M.1618668445.A.27B.html">[食記] 新北永和 RéeL法國鄉土料理~特別菜單</a>,
#  <a href="/bbs/Food/M.1618669115.A.1D8.html">[食記] 台北北投 無眠workshop 美味溫馨的早午餐</a>,
#  <a href="/bbs/Food/M.1618669833.A.33E.html">[食記] 豆莊豆漿店 新北板橋 酥脆可口雙蛋蛋餅</a>,
#  <a href="/bbs/Food/M.1618670212.A.F14.html">[食記] 台北南港CITYLINK 高麗園銅盤烤肉吃到飽 </a>,
#  <a href="/bbs/Food/M.1618671057.A.72B.html">[食記] 大村武串燒居酒屋士林店</a>,
#  <a href="/bbs/Food/M.1618671991.A.C38.html">[食記] 彰化市 老担阿璋肉圓 外皮Q彈人氣肉圓店</a>,
#  <a href="/bbs/Food/M.1618672176.A.BC5.html">[食記] 嘉義-綠豆先生後庄店-慶開幕買三送一，</a>,
#  <a href="/bbs/Food/M.1618672808.A.BDA.html">[食記] 台北.松山 - 深紅汕頭鍋物</a>,
#  <a href="/bbs/Food/M.1618673241.A.B50.html">[食記] 花蓮市區x小吃【黃車炸彈蔥油餅】</a>,
#  <a href="/bbs/Food/M.1618673249.A.179.html">[食記] 赤鬼新品牌台中開幕-花一番炸牛排</a>,
# ...

# %%
for titles in clean:
    print(titles.text)
# Out:
# [食記] 台北.大同 - 林家鯊魚煙
# [食記] 台北.大同 - 汕頭牛肉麵
# [食記] 台北.大同 - 阿寶師 鱔魚麵
# [食記] 新北永和 RéeL法國鄉土料理~特別菜單
# [食記] 台北北投 無眠workshop 美味溫馨的早午餐
# [食記] 豆莊豆漿店 新北板橋 酥脆可口雙蛋蛋餅
# [食記] 台北南港CITYLINK 高麗園銅盤烤肉吃到飽
# [食記] 大村武串燒居酒屋士林店
# [食記] 彰化市 老担阿璋肉圓 外皮Q彈人氣肉圓店
# [食記] 嘉義-綠豆先生後庄店-慶開幕買三送一，
# [食記] 台北.松山 - 深紅汕頭鍋物
# [食記] 花蓮市區x小吃【黃車炸彈蔥油餅】
# [食記] 赤鬼新品牌台中開幕-花一番炸牛排
# [食記] 永和阿義漁舖 精緻生魚丼180元就吃得到!
# [食記] 高雄 鳳山-吃否吃否 手撕豬肉堡&早午餐
# [食記] 台中 北屯區│大慶麵食館 軍功店
# [食記] 台南 國華街美食 黃家鱔魚意麵
# [食記] 台北 紅玉滿赤心-期間限定「神獸」雞蛋糕
# [食記] 台北中山 橫濱家系拉麵 特濃屋~道地日本
# [食記] 高雄 牛哥牛肉麵 果貿道地眷村美食
